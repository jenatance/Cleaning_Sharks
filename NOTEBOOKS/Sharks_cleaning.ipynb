# %% [markdown]
# # SHARKS CLEANING - ATTACKS TO MEN SINCE 2001

# %%
'''
# %pip install ipython
# %pip install seaborn
'''
# Out:
# '\n%pip install ipython\n%pip install seaborn\n'

# %%
import pandas as pd
pd.set_option('display.max_columns', None)

import numpy as np

import warnings
warnings.filterwarnings('ignore')

import pylab as plt
import seaborn as sns

# %matplotlib inline

# %%
sharks = pd.read_csv('../DATA/attacks.csv', encoding = "ISO-8859-1")

# %%
sharks.head()
# Out:
#   Case Number         Date    Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   Age  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F   57
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F   11
# 2                    Habush, Oahu      Surfing      John Denges    M   48
# 3              Arrawarra Headland      Surfing             male    M  NaN
# 4                        La Ticla  Free diving   Gustavo Ramos     M  NaN
#
#                                               Injury Fatal (Y/N)  \
# ...

# %%
sharks_ori_shape = sharks.shape
sharks_ori_shape
# Out:
# (25723, 24)

# %%
sharks.tail(20)  # podemos observar que al final de nuestro dataframe, hay muchas filas que no tienen ningún dato
# Out:
#       Case Number Date  Year Type Country Area Location Activity Name Sex   \
# 25703         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25704         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25705         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25706         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25707         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25708         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25709         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25710         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25711         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25712         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# 25713         NaN  NaN   NaN  NaN     NaN  NaN      NaN      NaN  NaN  NaN
# ...

# %%
sharks = sharks.dropna(how = 'all') # eliminamos las filas que tengan todo nulo

# %%
sharks.shape, sharks_ori_shape # tamaño del df ahora vs al inicio
# Out:
# ((8703, 24), (25723, 24))

# %%
sharks # vemos que todavía tenemos muchas filas con muchos nulos
# Out:
#       Case Number         Date    Year        Type    Country  \
# 0      2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1      2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2      2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3      2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4      2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
# ...           ...          ...     ...         ...        ...
# 8698            0          NaN     NaN         NaN        NaN
# 8699            0          NaN     NaN         NaN        NaN
# 8700            0          NaN     NaN         NaN        NaN
# 8701            0          NaN     NaN         NaN        NaN
# 25722          xx          NaN     NaN         NaN        NaN
#
#                   Area                        Location     Activity  \
# 0           California     Oceanside, San Diego County     Paddling
# 1              Georgia  St. Simon Island, Glynn County     Standing
# ...

# %%
sharks = sharks[sharks.isna().sum(axis=1) < 10]

# %%
sharks
# Out:
#      Case Number         Date    Year        Type             Country  \
# 0     2018.06.25  25-Jun-2018  2018.0     Boating                 USA
# 1     2018.06.18  18-Jun-2018  2018.0  Unprovoked                 USA
# 2     2018.06.09  09-Jun-2018  2018.0     Invalid                 USA
# 3     2018.06.08  08-Jun-2018  2018.0  Unprovoked           AUSTRALIA
# 4     2018.06.04  04-Jun-2018  2018.0    Provoked              MEXICO
# ...          ...          ...     ...         ...                 ...
# 6297     ND.0005  Before 1903     0.0  Unprovoked           AUSTRALIA
# 6298     ND.0004  Before 1903     0.0  Unprovoked           AUSTRALIA
# 6299     ND.0003    1900-1905     0.0  Unprovoked                 USA
# 6300     ND.0002    1883-1889     0.0  Unprovoked              PANAMA
# 6301     ND.0001    1845-1853     0.0  Unprovoked  CEYLON (SRI LANKA)
#
#                    Area                             Location      Activity  \
# ...

# %%
sharks.shape, sharks_ori_shape # tamaño del df ahora vs al inicio
# Out:
# ((6295, 24), (25723, 24))

# %%
sharks.info() # vemos las columnas con su tipo de variable y los no nulos que tienen cada una
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6295 entries, 0 to 6301
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             6294 non-null   object
#  1   Date                    6295 non-null   object
#  2   Year                    6293 non-null   float64
#  3   Type                    6291 non-null   object
#  4   Country                 6246 non-null   object
#  5   Area                    5847 non-null   object
#  6   Location                5761 non-null   object
#  7   Activity                5757 non-null   object
#  8   Name                    6090 non-null   object
#  9   Sex                     5736 non-null   object
#  10  Age                     3471 non-null   object
#  11  Injury                  6269 non-null   object
#  12  Fatal (Y/N)             5759 non-null   object
#  13  Time                    2948 non-null   object
# ...

# %%
# Las columnas Unnamed: 22 y Unnamed: 23 tendríamos que rellenarlas con datos, en este caso, al ser de tipo Object, con un String 'desconocido'

# %%
sharks[['Unnamed: 22', 'Unnamed: 23']] = sharks[['Unnamed: 22', 'Unnamed: 23']].fillna('Unknown')

# %%
nanCols = sharks.isna().sum()
nanCols[nanCols > 0]
# Out:
# Case Number                  1
# Year                         2
# Type                         4
# Country                     49
# Area                       448
# Location                   534
# Activity                   538
# Name                       205
# Sex                        559
# Age                       2824
# Injury                      26
# Fatal (Y/N)                536
# Time                      3347
# Species                   2833
# Investigator or Source      16
# href formula                 1
# dtype: int64

# %%
nanCols = sharks.isna().sum()
nanCols[nanCols > 1000]
# Out:
# Age         2824
# Time        3347
# Species     2833
# dtype: int64

# %%
# Mirando los valores no nulos, deberíamos mirar la columna 'age', la columna 'time' y la columna 'species'

# %%
sharks[['Age','Time','Species ']]
# Out:
#       Age           Time         Species
# 0      57          18h00      White shark
# 1      11  14h00  -15h00              NaN
# 2      48          07h45              NaN
# 3     NaN            NaN        2 m shark
# 4     NaN            NaN  Tiger shark, 3m
# ...   ...            ...              ...
# 6297  NaN            NaN              NaN
# 6298  NaN            NaN              NaN
# 6299  NaN            NaN              NaN
# 6300  NaN            NaN              NaN
# 6301   15            NaN              NaN
#
# [6295 rows x 3 columns]

# %%
# La columna species tiene un espacio, sería conveniente mirar todos los nombres de columnas y cambiarlos para que tuvieran el mismo formato

# %%
columns_names = sharks.columns.values
columns_names
# Out:
# array(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area',
#        'Location', 'Activity', 'Name', 'Sex ', 'Age', 'Injury',
#        'Fatal (Y/N)', 'Time', 'Species ', 'Investigator or Source', 'pdf',
#        'href formula', 'href', 'Case Number.1', 'Case Number.2',
#        'original order', 'Unnamed: 22', 'Unnamed: 23'], dtype=object)

# %%
sharks.rename(columns={'Case Number': 'caseNumber', 'Date': 'date', 'Year': 'year', 'Type': 'type', 'Country': 'country', 'Area': 'area',
       'Location': 'location', 'Activity': 'activity', 'Name': 'name', 'Sex ': 'sex', 'Age': 'age', 'Injury': 'injury',
       'Fatal (Y/N)': 'fatal(y/n)', 'Time': 'time', 'Species ': 'species', 'Investigator or Source': 'investigatorOrSource', 'pdf': 'pdf',
       'href formula': 'hrefFormula', 'href': 'href', 'Case Number.1': 'caseNumber1', 'Case Number.2': 'caseNumber2',
       'original order': 'originalOrder', 'Unnamed: 22': 'unnamed22', 'Unnamed: 23': 'unnamed23'}, inplace=True)

# %%
print(sharks['year'].unique())
# Out:
# [2018. 2017.   nan 2016. 2015. 2014. 2013. 2012. 2011. 2010. 2009. 2008.
#  2007. 2006. 2005. 2004. 2003. 2002. 2001. 2000. 1999. 1998. 1997. 1996.
#  1995. 1984. 1994. 1993. 1992. 1991. 1990. 1989. 1969. 1988. 1987. 1986.
#  1985. 1983. 1982. 1981. 1980. 1979. 1978. 1977. 1976. 1975. 1974. 1973.
#  1972. 1971. 1970. 1968. 1967. 1966. 1965. 1964. 1963. 1962. 1961. 1960.
#  1959. 1958. 1957. 1956. 1955. 1954. 1953. 1952. 1951. 1950. 1949. 1948.
#  1848. 1947. 1946. 1945. 1944. 1943. 1942. 1941. 1940. 1939. 1938. 1937.
#  1936. 1935. 1934. 1933. 1932. 1931. 1930. 1929. 1928. 1927. 1926. 1925.
#  1924. 1923. 1922. 1921. 1920. 1919. 1918. 1917. 1916. 1915. 1914. 1913.
#  1912. 1911. 1910. 1909. 1908. 1907. 1906. 1905. 1904. 1903. 1902. 1901.
#  1900. 1899. 1898. 1897. 1896. 1895. 1894. 1893. 1892. 1891. 1890. 1889.
#  1888. 1887. 1886. 1885. 1884. 1883. 1882. 1881. 1880. 1879. 1878. 1877.
#  1876. 1875. 1874. 1873. 1872. 1871. 1870. 1869. 1868. 1867. 1866. 1865.
# ...

# %%
print(sharks['sex'].unique())
# Out:
# ['F' 'M' nan 'M ' 'lli' 'N' '.']

# %%
sharks.shape, sharks_ori_shape # tamaño del df ahora vs al inicio
# Out:
# ((6295, 24), (25723, 24))

# %%
indexNames = sharks[ sharks['year'] < 2001 ].index # índices de los ataques antes de 2001
sharks.drop(indexNames, inplace=True) # quitamos de nuestro dataframe los índices que hemos hallado previamente
indexNames = sharks[ sharks['sex'] == 'F' ].index # índices de los ataques a mujeres
sharks.drop(indexNames, inplace=True) # quitamos de nuestro dataframe los índices que hemos hallado previamente
indexNames = sharks[ sharks['sex'] == 'lli' ].index # índices de los ataques a otros
sharks.drop(indexNames, inplace=True) # quitamos de nuestro dataframe los índices que hemos hallado previamente

# %%
sharks = sharks[sharks['year'].notna()]
sharks = sharks[sharks['sex'].notna()]

# %%
sharks.sex = sharks.sex.str.replace('M ', 'M') # para poner todos los datos de género con el mismo formato

# %%
print(sharks['year'].unique())
# Out:
# [2018. 2017. 2016. 2015. 2014. 2013. 2012. 2011. 2010. 2009. 2008. 2007.
#  2006. 2005. 2004. 2003. 2002. 2001.]

# %%
print(sharks['sex'].unique())
# Out:
# ['M']

# %%
sharks.shape, sharks_ori_shape # tamaño del df solo con los datos de los ataques a hombres desde 2001 vs al inicio
# Out:
# ((1558, 24), (25723, 24))

# %%
nanCols = sharks.isna().sum()
nanCols[nanCols > 0]
# Out:
# type                      2
# country                   2
# area                     67
# location                 71
# activity                 52
# name                      9
# age                     347
# injury                    1
# fatal(y/n)              114
# time                    428
# species                 528
# investigatorOrSource      5
# dtype: int64

# %%
print(sharks['type'].unique())
# Out:
# ['Invalid' 'Unprovoked' 'Provoked' 'Questionable' nan 'Boating' 'Boat'
#  'Sea Disaster' 'Boatomg']

# %%
sharks.type = sharks.type.str.replace('Boating', 'Boat')
sharks.type = sharks.type.str.replace('Boatomg', 'Boat')
sharks.type = sharks.type.str.replace('Boat', 'Boating')

# %%
print(sharks['type'].unique())
# Out:
# ['Invalid' 'Unprovoked' 'Provoked' 'Questionable' nan 'Boating'
#  'Sea Disaster']

# %%
display(sharks[sharks['type'].isnull()]) # para ver qué ocurre con los valores nulos de type
# Out:
#        caseNumber         date    year type    country           area  \
# 85   2017.09.15.a  15-Sep-2017  2017.0  NaN      SAMOA   Upolu Island
# 382    2015.07.27  27-Jul-2015  2015.0  NaN  AUSTRALIA       Victoria
#
#              location activity  name sex  age                      injury  \
# 85          Nofoalii  Fishing  male   M  NaN  Injuries to hands and legs
# 382  Tyrendarra Beach  Surfing  male   M   40              Injury to hand
#
#     fatal(y/n)   time species       investigatorOrSource  \
# 85           N  Night     NaN  Samoa Observer, 9/16/2017
# 382        NaN    NaN     NaN                        NaN
#
#                          pdf  \
# 85    2017.09.15.a-Samoa.pdf
# 382  2015.07.27-Victoria.pdf
#
#                                            hrefFormula  \
# 85   http://sharkattackfile.net/spreadsheets/pdf_di...
# 382  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                   href   caseNumber1  \
# ...

# %%
sharks.loc[85,'type'] = ['Unprovoked']
sharks.loc[382,'type'] = ['Unprovoked']

# %%
print(sharks['country'].unique())
# Out:
# ['USA' 'AUSTRALIA' 'MEXICO' 'BRAZIL' 'ENGLAND' 'SOUTH AFRICA' 'THAILAND'
#  'COSTA RICA' 'MALDIVES' 'BAHAMAS' 'ECUADOR' 'NEW CALEDONIA' 'MALAYSIA'
#  nan 'CUBA' 'MAURITIUS' 'NEW ZEALAND' 'SPAIN' 'SAMOA' 'SOLOMON ISLANDS'
#  'JAPAN' 'ST HELENA, British overseas territory' 'REUNION'
#  'FRENCH POLYNESIA' 'UNITED KINGDOM' 'UNITED ARAB EMIRATES' 'PHILIPPINES'
#  'INDONESIA' 'CHINA' 'COLUMBIA' 'EGYPT' 'CAPE VERDE' 'Fiji'
#  'CAYMAN ISLANDS' 'ARUBA' 'MOZAMBIQUE' 'FIJI' 'PUERTO RICO' 'ITALY'
#  'ST. MARTIN' 'FRANCE' 'PAPUA NEW GUINEA' 'TRINIDAD & TOBAGO' 'KIRIBATI'
#  'ISRAEL' 'DIEGO GARCIA' 'TAIWAN' 'JAMAICA' 'PALESTINIAN TERRITORIES'
#  'GUAM' 'SEYCHELLES' 'SCOTLAND' 'SAUDI ARABIA' 'CHILE' 'ANTIGUA'
#  'DOMINICAN REPUBLIC' 'KENYA' 'RUSSIA' 'TURKS & CAICOS'
#  'UNITED ARAB EMIRATES (UAE)' 'AZORES' 'TONGA' 'MALTA' 'VIETNAM'
#  'MADAGASCAR' 'SOMALIA' 'NEVIS' 'CROATIA' 'PANAMA'
#  'BRITISH VIRGIN ISLANDS' 'NORWAY' 'BELIZE' 'Sierra Leone'
# ...

# %%
sharks['country'] = sharks['country'].str.lower()

# %%
display(sharks[sharks['country'].isnull()])
# Out:
#        caseNumber                  date    year        type country area  \
# 62   2017.11.13.R  Reported 13-Nov-2017  2017.0  Unprovoked     NaN  NaN
# 525    2014.08.00              Aug-2014  2014.0     Invalid     NaN  NaN
#
#     location      activity            name sex  age  \
# 62       NaN       Surfing   Timur Yunusov   M   24
# 525      NaN  Sea disaster  Cuban refugees   M  NaN
#
#                                              injury fatal(y/n) time  \
# 62                          Puncture wounds to feet          N  NaN
# 525  Shark involvement prior to death not confirmed        NaN  NaN
#
#                              species          investigatorOrSource  \
# 62                               NaN                     Instagram
# 525  Shark involvement not confirmed  Associated Press, 11/27/2014
#
#                                pdf  \
# 62          2017.11.13.R-Timur.pdf
# 525  2014.08.00-Cuban-refugees.pdf
#
#                                            hrefFormula  \
# ...

# %%
sharks.loc[62,'country'] = ['Unknown']
sharks.loc[525,'country'] = ['Unknown']

# %%
sharks[['name']] = sharks[['name']].fillna('Unknown')

# %%
print(sharks['age'].unique())
# Out:
# ['48' nan '18' '52' '15' '12' '32' '10' '21' '30' '60' '33' '29' '54' '34'
#  '41' '37' '56' '19' '25' '69' '38' '35' '45' '14' '40s' '28' '20' '24'
#  '26' '22' '7' '31' '17' '13' '42' '40' '50' '46' '82' '73' '68' '16' '39'
#  '58' 'Teen' '55' '57' '47' '61' '65' '36' '43' '60s' '9' '49' '72' '59'
#  '11' '27' '64' '23' '71' '44' '62' '6' '63' '70' '18 months' '53' '50s'
#  '8' '51' 'teen' '66' '77' '74' '3' '28 & 26' '30s' '5' '86' '12 or 13'
#  '46 & 34' 'Teens' '84' '\xa0 ' ' ' '30 or 36' '6½' '21 & ?' '75'
#  '33 or 37' 'mid-30s']

# %%
sharks[['age']] = sharks[['age']].fillna('-1')

# %%
sharks.age = sharks.age.str.replace('40s', '40')
sharks.age = sharks.age.str.replace('Teen', '15')
sharks.age = sharks.age.str.replace('60s', '60')
sharks.age = sharks.age.str.replace('18 months', '0')
sharks.age = sharks.age.str.replace('50s', '50')
sharks.age = sharks.age.str.replace('teen', '15')
sharks.age = sharks.age.str.replace('28 & 26', '27')
sharks.age = sharks.age.str.replace('30s', '30')
sharks.age = sharks.age.str.replace('46 & 34', '40')
sharks.age = sharks.age.str.replace('15s', '15')
sharks.age = sharks.age.str.replace('\xa0 ', '-1')
sharks.age = sharks.age.str.replace('30 or 36', '33')
sharks.age = sharks.age.str.replace('6½', '6')
sharks.age = sharks.age.str.replace('21 & ?', '21')
sharks.age = sharks.age.str.replace('33 or 37', '35')
sharks.age = sharks.age.str.replace('mid-30', '35')
sharks.age = sharks.age.str.replace('12 or 13', '12')

# %%
sharks.age = sharks.age.str.replace(' ', '-1')

# %%
print(sharks['age'].unique())
# Out:
# ['48' '-1' '18' '52' '15' '12' '32' '10' '21' '30' '60' '33' '29' '54'
#  '34' '41' '37' '56' '19' '25' '69' '38' '35' '45' '14' '40' '28' '20'
#  '24' '26' '22' '7' '31' '17' '13' '42' '50' '46' '82' '73' '68' '16' '39'
#  '58' '55' '57' '47' '61' '65' '36' '43' '9' '49' '72' '59' '11' '27' '64'
#  '23' '71' '44' '62' '6' '63' '70' '0' '53' '8' '51' '66' '77' '74' '3'
#  '5' '86' '84' '21?' '75']

# %%
display(sharks[sharks['age'] == '21?'])
# Out:
#       caseNumber         date    year        type   country             area  \
# 1925  2001.08.12  12-Aug-2001  2001.0  Unprovoked  thailand  Rayong Province
#
#                 location              activity                  name sex  age  \
# 1925  Laem Mae Pim Beach  Fell off banana boat  O. Jaimaung & friend   M  21?
#
#            injury fatal(y/n) time          species investigatorOrSource  \
# 1925  Legs bitten          N  NaN  3 m [10'] shark          O. Jaimuang
#
#                           pdf  \
# 1925  2001.08.12-Jaimuang.pdf
#
#                                             hrefFormula  \
# 1925  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href caseNumber1  \
# 1925  http://sharkattackfile.net/spreadsheets/pdf_di...  2001.08.12
#
#      caseNumber2  originalOrder unnamed22 unnamed23
# 1925  2001.08.12         4378.0   Unknown   Unknown

# %%
sharks.loc[1925,'age'] = ['21']

# %%
print(sharks['age'].unique())
# Out:
# ['48' '-1' '18' '52' '15' '12' '32' '10' '21' '30' '60' '33' '29' '54'
#  '34' '41' '37' '56' '19' '25' '69' '38' '35' '45' '14' '40' '28' '20'
#  '24' '26' '22' '7' '31' '17' '13' '42' '50' '46' '82' '73' '68' '16' '39'
#  '58' '55' '57' '47' '61' '65' '36' '43' '9' '49' '72' '59' '11' '27' '64'
#  '23' '71' '44' '62' '6' '63' '70' '0' '53' '8' '51' '66' '77' '74' '3'
#  '5' '86' '84' '75']

# %%
display(sharks[sharks['injury'].isnull()])
# Out:
#         caseNumber         date    year        type    country  \
# 1270  2008.04.20.a  20-Apr-2008  2008.0  Unprovoked  australia
#
#                  area       location activity             name sex age injury  \
# 1270  New South Wales  Crescent Head      NaN  Jamie Adlington   M  -1    NaN
#
#      fatal(y/n) time             species investigatorOrSource  \
# 1270    UNKNOWN  NaN  Tiger shark, 2.3m        T. Peake, GSAF
#
#                              pdf  \
# 1270  2008.04.20.a-Adlington.pdf
#
#                                             hrefFormula  \
# 1270  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href   caseNumber1  \
# 1270  http://sharkattackfile.net/spreadsheets/pdf_di...  2008.04.20.a
#
#        caseNumber2  originalOrder unnamed22 unnamed23
# 1270  2008.04.20.a         5033.0   Unknown   Unknown

# %%
sharks[['injury']] = sharks[['injury']].fillna('Unknown')

# %%
display(sharks[sharks['investigatorOrSource'].isnull()])
# Out:
#         caseNumber         date    year        type       country  \
# 119   2017.07.14.a  14-Jul-2017  2017.0  Unprovoked     australia
# 290   2016.04.07.b  07-Apr-2016  2016.0  Unprovoked           usa
# 382     2015.07.27  27-Jul-2015  2015.0  Unprovoked     australia
# 631   2013.08.31.b  31-Aug-2013  2013.0  Unprovoked       bahamas
# 1242  2008.06.28.a  28-Jun-2008  2008.0  Unprovoked  south africa
#
#                        area                     location      activity  \
# 119       Western Australia                Floreat Beach       Surfing
# 290                 Florida  Florida Keys, Monroe County       Fishing
# 382                Victoria             Tyrendarra Beach       Surfing
# 631                     NaN               Freetown Beach  Spearfishing
# 1242  Western Cape Province                   Mossel Bay  Surf skiing
#
#                  name sex age                         injury fatal(y/n)  \
# ...

# %%
sharks[['investigatorOrSource']] = sharks[['investigatorOrSource']].fillna('Unknown')

# %%
print(sharks['fatal(y/n)'].unique())
# Out:
# ['N' 'Y' nan 'M' '2017' 'UNKNOWN']

# %%
display(sharks[sharks['fatal(y/n)'] == 'UNKNOWN'])
# Out:
#         caseNumber         date    year        type    country  \
# 1270  2008.04.20.a  20-Apr-2008  2008.0  Unprovoked  australia
#
#                  area       location activity             name sex age  \
# 1270  New South Wales  Crescent Head      NaN  Jamie Adlington   M  -1
#
#        injury fatal(y/n) time             species investigatorOrSource  \
# 1270  Unknown    UNKNOWN  NaN  Tiger shark, 2.3m        T. Peake, GSAF
#
#                              pdf  \
# 1270  2008.04.20.a-Adlington.pdf
#
#                                             hrefFormula  \
# 1270  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href   caseNumber1  \
# 1270  http://sharkattackfile.net/spreadsheets/pdf_di...  2008.04.20.a
#
#        caseNumber2  originalOrder unnamed22 unnamed23
# 1270  2008.04.20.a         5033.0   Unknown   Unknown

# %%
sharks.loc[1270,'fatal(y/n)'] = ['N']

# %%
display(sharks[sharks['fatal(y/n)'] == '2017'])
# Out:
#      caseNumber         date    year      type country      area  location  \
# 786  2012.06.10  10-Jun-2012  2012.0  Provoked   italy  Sardinia  Muravera
#
#                                             activity          name sex age  \
# 786  Attempting to rescue an injured & beached shark  Giorgio Zara   M  57
#
#                                        injury fatal(y/n)     time  \
# 786  Lower left leg injured PROVOKED ACCIDENT       2017  Morning
#
#               species investigatorOrSource                  pdf  \
# 786  Blue shark, 2.5m  D. Puddo, 6/11/2012  2012.06.10-Zara.pdf
#
#                                            hrefFormula  \
# 786  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                   href caseNumber1  \
# 786  http://sharkattackfile.net/spreadsheets/pdf_di...  2012.06.10
#
#     caseNumber2  originalOrder unnamed22 unnamed23
# 786  2012.06.10         5517.0   Unknown   Unknown

# %%
sharks.loc[786,'fatal(y/n)'] = ['N']

# %%
display(sharks[sharks['fatal(y/n)'] == 'M'])
# Out:
#        caseNumber         date    year      type           country      area  \
# 285  2016.04.18.b  18-Apr-2016  2016.0  Provoked  french polynesia  Tuamotos
#
#          location      activity         name sex age  \
# 285  Makemo Atoll  Spearfishing  Hoata Iotua   M  22
#
#                                                 injury fatal(y/n)     time  \
# 285  Laceration to knee by speared shark PROVOKED I...          M  Morning
#
#                   species  investigatorOrSource                     pdf  \
# 285  Grey reef shark, 2 m  TNTV News, 4/19/2016  2016.04.18.b-Iotua.pdf
#
#                                            hrefFormula  \
# 285  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                   href   caseNumber1  \
# 285  http://sharkattackfile.net/spreadsheets/pdf_di...  2016.04.18.b
#
#       caseNumber2  originalOrder unnamed22 unnamed23
# 285  2016.04.18.b         6018.0   Unknown   Unknown

# %%
sharks.loc[285,'fatal(y/n)'] = ['N']

# %%
fatalInjuries = (sharks[sharks['fatal(y/n)'].isnull()]) 
fatalInjuries.head(10)
# Out:
#        caseNumber         date    year        type       country  \
# 27   2018.04.15.c  15-Apr-2018  2018.0  Unprovoked        brazil
# 76     2017.10.01  01-Oct-2017  2017.0     Invalid  south africa
# 79   2017.09.24.b  24-Sep-2017  2017.0     Invalid           usa
# 84   2017.09.15.b  15-Sep-2017  2017.0     Invalid  south africa
# 107  2017.07.29.c  29-Jul-2017  2017.0     Invalid           usa
# 125    2017.06.29  29-Jun-2017  2017.0     Invalid           usa
# 153    2017.04.20  20-Apr-2017  2017.0     Invalid           usa
# 159  2017.04.12.a  12-Apr-2017  2017.0     Invalid  south africa
# 189    2017.01.03  03-Jan-2017  2017.0     Invalid     australia
# 195  2016.12.11.a  11-Dec-2016  2016.0     Invalid           usa
#
#                       area                             location      activity  \
# 27              Pernambuco                              Piedade      Swimming
# 76   Western Cape Province                          Dyer Island  Scuba Diving
# ...

# %%
fatalInjuries.loc[76,'fatal(y/n)'] = 'Y'
fatalInjuries.loc[84,'fatal(y/n)'] = 'Y'
fatalInjuries.loc[159,'fatal(y/n)'] = 'Y'
fatalInjuries.loc[437,'fatal(y/n)'] = 'Y'
fatalInjuries.loc[525,'fatal(y/n)'] = 'Y'
fatalInjuries.loc[437:570,'fatal(y/n)'] = 'Y'
fatalInjuries.loc[660:688,'fatal(y/n)'] = 'Y'
fatalInjuries.loc[763,'fatal(y/n)'] = 'Y'
fatalInjuries.loc[874,'fatal(y/n)'] = 'Y'
fatalInjuries.loc[890,'fatal(y/n)'] = 'Y'
fatalInjuries.loc[967:1044,'fatal(y/n)'] = 'Y'
fatalInjuries.loc[1093,'fatal(y/n)'] = 'Y'
fatalInjuries.loc[1136:1212,'fatal(y/n)'] = 'Y'
fatalInjuries.loc[1240,'fatal(y/n)'] = 'Y'
fatalInjuries.loc[1272,'fatal(y/n)'] = 'Y'
fatalInjuries.loc[1301,'fatal(y/n)'] = 'Y'
fatalInjuries.loc[1381:1407,'fatal(y/n)'] = 'Y'
fatalInjuries.loc[1433:1499,'fatal(y/n)'] = 'Y'
fatalInjuries.loc[1563,'fatal(y/n)'] = 'Y'
fatalInjuries.loc[1606,'fatal(y/n)'] = 'Y'
fatalInjuries.loc[1696,'fatal(y/n)'] = 'Y'
fatalInjuries.loc[1799,'fatal(y/n)'] = 'Y'
fatalInjuries.loc[1866:1879,'fatal(y/n)'] = 'Y'
fatalInjuries.loc[1941:1947,'fatal(y/n)'] = 'Y'

# %%
fatalInjuries[['fatal(y/n)']] = fatalInjuries[['fatal(y/n)']].fillna('N') # los que no han sido mortales lo indicamos con N

# %%
mortalAttacksIndex = fatalInjuries[fatalInjuries['fatal(y/n)'] == 'Y' ].index
notMortalAttacksIndex = fatalInjuries[fatalInjuries['fatal(y/n)'] == 'N' ].index # con esto hayamos los indices de Y y N de fatalInjuries

# %%
sharks.loc[mortalAttacksIndex, 'fatal(y/n)'] = 'Y'
sharks.loc[notMortalAttacksIndex, 'fatal(y/n)'] = 'N' # sustituimos en el dataframe original los nulos de fatal con lo hallado previamente

# %%
sharks['fatal(y/n)'] = sharks['fatal(y/n)'].str.replace('Y', 'True')
sharks['fatal(y/n)'] = sharks['fatal(y/n)'].str.replace('N', 'False')

# %%
print(sharks['fatal(y/n)'].unique())
# Out:
# ['False' 'True']

# %%
print(sharks['caseNumber'].unique())
# Out:
# ['2018.06.09' '2018.06.08' '2018.06.04' ... '2001.01.24.R' '2001.01.09'
#  '2001.01.06']

# %%
'''
for i,row in sharks.iterrows():
    print(i, row['caseNumber'])
'''
# Out:
# "\nfor i,row in sharks.iterrows():\n    print(i, row['caseNumber'])\n"

# %%
sharks.caseNumber = sharks.caseNumber.str.replace('.b', '')
sharks.caseNumber = sharks.caseNumber.str.replace('.a', '')
sharks.caseNumber = sharks.caseNumber.str.replace('.R', '')
sharks.caseNumber = sharks.caseNumber.str.replace('.c', '')
sharks.caseNumber = sharks.caseNumber.str.replace('.d', '')
sharks.caseNumber = sharks.caseNumber.str.replace('.e', '')

# %%
sharks.loc[847,'caseNumber'] = ['2011.10.29']
sharks.loc[882,'caseNumber'] = ['2011.08.17']
sharks.loc[1135,'caseNumber'] = ['2009.04.17']
sharks.loc[1346,'caseNumber'] = ['2007.08.19']
sharks.loc[370,'caseNumber'] = ['2015.09.01']
sharks.loc[504,'caseNumber'] = ['2014.09.01']
sharks.loc[525,'caseNumber'] = ['2014.08.01']
sharks.loc[588,'caseNumber'] = ['2014.01.01']
sharks.loc[802,'caseNumber'] = ['2012.04.01']
sharks.loc[1024,'caseNumber'] = ['2010.06.01']
sharks.loc[1187,'caseNumber'] = ['2008.12.01']
sharks.loc[1210,'caseNumber'] = ['2008.09.01']
sharks.loc[1239,'caseNumber'] = ['2008.07.01']
sharks.loc[1298,'caseNumber'] = ['2008.10.01']
sharks.loc[1299,'caseNumber'] = ['2008.08.01']
sharks.loc[1314,'caseNumber'] = ['2007.11.01']
sharks.loc[1403,'caseNumber'] = ['2007.02.01']
sharks.loc[1448,'caseNumber'] = ['2006.08.01']
sharks.loc[1709,'caseNumber'] = ['2004.01.01']
sharks.loc[1724,'caseNumber'] = ['2003.11.01']
sharks.loc[1748,'caseNumber'] = ['2003.09.01']
sharks.loc[1760,'caseNumber'] = ['2003.07.01']
sharks.loc[1761,'caseNumber'] = ['2003.07.01']
sharks.loc[1762,'caseNumber'] = ['2003.07.01']
sharks.loc[1814,'caseNumber'] = ['2002.11.01']
sharks.loc[1938,'caseNumber'] = ['2001.07.01']
sharks.loc[1951,'caseNumber'] = ['2001.05.01']

# %%
'''
for i,row in sharks.iterrows():
    print(i, row['date'])
'''
# Out:
# "\nfor i,row in sharks.iterrows():\n    print(i, row['date'])\n"

# %%
sharks.date = sharks.date.str.replace('Reported ', '')
sharks.loc[37,'date'] = ['09.Mar.2018']
sharks.loc[38,'date'] = ['09.Mar.2018']
sharks.loc[131,'date'] = ['05.Jun.2017']
sharks.loc[248,'date'] = ['14.Jul.2016']
sharks.loc[304,'date'] = ['19.Feb.2016']
sharks.loc[370,'date'] = ['01.Sep.2015']
sharks.loc[423,'date'] = ['20.May.2015']
sharks.loc[504,'date'] = ['01.Sep.2014']
sharks.loc[525,'date'] = ['01.Aug.2014']
sharks.loc[534,'date'] = ['09.Jul.2014']
sharks.loc[535,'date'] = ['05.Jul.2014']
sharks.loc[536,'date'] = ['05.Jul.2014']
sharks.loc[537,'date'] = ['03.Jul.2014']
sharks.loc[588,'date'] = ['01.Jan.2014']
sharks.loc[619,'date'] = ['25.Sep.2013']
sharks.loc[620,'date'] = ['21.Sep.2013']
sharks.loc[621,'date'] = ['21.Sep.2013']
sharks.loc[622,'date'] = ['14.Sep.2013']
sharks.loc[625,'date'] = ['07.Sep.2013']
sharks.loc[626,'date'] = ['07.Sep.2013']
sharks.loc[627,'date'] = ['02.Sep.2013']
sharks.loc[628,'date'] = ['01.Sep.2013']
sharks.loc[629,'date'] = ['01.Sep.2013']
sharks.loc[630,'date'] = ['01.Sep.2013']
sharks.loc[636,'date'] = ['25.Aug.2013']
sharks.loc[637,'date'] = ['18.Aug.2013']
sharks.loc[643,'date'] = ['05.Aug.2013']
sharks.loc[645,'date'] = ['30.Jul.2013']
sharks.loc[648,'date'] = ['29.Jul.2013']
sharks.loc[767,'date'] = ['07.Jul.2012']
sharks.loc[802,'date'] = ['01.Apr.2012']
sharks.loc[847,'date'] = ['29.Oct.2011']
sharks.loc[885,'date'] = ['16.Aug.2011']
sharks.loc[888,'date'] = ['11.Aug.2011']
sharks.loc[987,'date'] = ['13.Sep.2010']
sharks.loc[990,'date'] = ['04.Sep.2010']
sharks.loc[1024,'date'] = ['01.Jun.2010']
sharks.loc[1035,'date'] = ['27.Mar.2010']
sharks.loc[1036,'date'] = ['19.Feb.2010']
sharks.loc[1102,'date'] = ['31.Jul.2009']
sharks.loc[1187,'date'] = ['01.Dec.2008']
sharks.loc[1210,'date'] = ['01.Sep.2008']
sharks.loc[1239,'date'] = ['01.Jul.2008']
sharks.loc[1292,'date'] = ['30.Jan.2008']
sharks.loc[1298,'date'] = ['01.Oct.2008']
sharks.loc[1299,'date'] = ['01.Aug.2008']
sharks.loc[1314,'date'] = ['01.Nov.2007']
sharks.loc[1357,'date'] = ['19.Jul.2007']
sharks.loc[1358,'date'] = ['19.Jul.2007']
sharks.loc[1403,'date'] = ['01.Feb.2007']
sharks.loc[1448,'date'] = ['01.Aug.2006']
sharks.loc[1462,'date'] = ['09.Jul.2006']
sharks.loc[1466,'date'] = ['30.Jun.2006']
sharks.loc[1485,'date'] = ['23.Apr.2006']
sharks.loc[1493,'date'] = ['28.Mar.2006']
sharks.loc[1544,'date'] = ['27.Sep.2005']
sharks.loc[1562,'date'] = ['06.Aug.2005']
sharks.loc[1563,'date'] = ['01.Aug.2005']
sharks.loc[1573,'date'] = ['27.Jun.2005']
sharks.loc[1602,'date'] = ['27.Mar.2005']
sharks.loc[1709,'date'] = ['01.Jan.2004']
sharks.loc[1724,'date'] = ['01.Nov.2003']
sharks.loc[1748,'date'] = ['01.Sep.2003']
sharks.loc[1760,'date'] = ['01.Jul.2003']
sharks.loc[1761,'date'] = ['01.Jul.2003']
sharks.loc[1762,'date'] = ['01.Jul.2003']
sharks.loc[1814,'date'] = ['01.Nov.2002']
sharks.loc[1938,'date'] = ['01.Jul.2001']
sharks.loc[1951,'date'] = ['01.May.2001']
sharks.loc[1977,'date'] = ['24.Jan.2001']

# %%
sharks[['area']] = sharks[['area']].fillna('Unknown')
sharks[['location']] = sharks[['location']].fillna('Unknown')
sharks[['activity']] = sharks[['activity']].fillna('Unknown')
sharks[['species']] = sharks[['species']].fillna('Unknown')

# %%
'''
for i,row in sharks.iterrows():
    print(i, row['time'])
'''
# Out:
# "\nfor i,row in sharks.iterrows():\n    print(i, row['time'])\n"

# %%
sharks.time = sharks.time.str.replace('h', '.')
sharks.time = sharks.time.str.replace('Late afternoon', '17.00')
sharks.time = sharks.time.str.replace('Morning', '07.00')
sharks.time = sharks.time.str.replace('Afternoon', '19.00')
sharks.time = sharks.time.str.replace('After noon', '23.00')
sharks.time = sharks.time.str.replace('Early afternoon', '16.00')
sharks.time = sharks.time.str.replace('0830', '08.30')
sharks.time = sharks.time.str.replace('Just before noon', '23.00')
sharks.time = sharks.time.str.replace('Early morning', '06.00')
sharks.time = sharks.time.str.replace('Midday', '12.00')
sharks.time = sharks.time.str.replace('Dusk', '18.00')
sharks.time = sharks.time.str.replace('Sunset', '20.00')
sharks.time = sharks.time.str.replace('"Evening"', '20.00')
sharks.time = sharks.time.str.replace('Just before sundown', '05.00')
sharks.time = sharks.time.str.replace('--', '-1.00')
sharks.time = sharks.time.str.replace('Morning', '07.00')
sharks.time = sharks.time.str.replace('Early Morning', '06.00')
sharks.time = sharks.time.str.replace('Late morning', '11.00')
sharks.time = sharks.time.str.replace('P.M.', '17.00')
sharks.time = sharks.time.str.replace('8:04 pm', '20.00')
sharks.time = sharks.time.str.replace('Nig.t', '22.00')
sharks.time = sharks.time.str.replace('Midnig.t', '00.00')
sharks.time = sharks.time.str.replace('09.30 / 10.00', '10.00')
sharks.time = sharks.time.str.replace('10.45-11.15', '11.00')
sharks.time = sharks.time.str.replace('Evening', '20.00')
sharks.time = sharks.time.str.replace('Sometime between 06.00 & 08.oo', '07.00')
sharks.time = sharks.time.str.replace('07.00 - 08.00', '07.00')
sharks.time = sharks.time.str.replace('18.15-18.30', '18.15')
sharks.time = sharks.time.str.replace('09.00 - 09.30', '09.00')
sharks.time = sharks.time.str.replace('Dawn', '06.00')
sharks.time = sharks.time.str.replace('AM', '06.00')
sharks.time = sharks.time.str.replace('Lunc.time', '13.00')
sharks.time = sharks.time.str.replace('0500', '05.00')
sharks.time = sharks.time.str.replace('Before 07.00', '07.00')
sharks.time = sharks.time.str.replace('10.00 00.00 11.00', '10.00')
sharks.time = sharks.time.str.replace('"Just before 11.00"', '11.00')
sharks.time = sharks.time.str.replace('11.115', '11.15')
sharks.time = sharks.time.str.replace('Between 05.00 and 08.00', '07.00')
sharks.time = sharks.time.str.replace('17.00 or 17.40', '17.00')
sharks.time = sharks.time.str.replace('>08.00', '08.00')
sharks.time = sharks.time.str.replace('Just after 12.00', '12.00')
sharks.time = sharks.time.str.replace('Early 07.00', '07.00')
sharks.time = sharks.time.str.replace('S.ortly after midnig.t', '00.00')
sharks.time = sharks.time.str.replace('\xa0 ', '-1.00')
sharks.time = sharks.time.str.replace('09.00 -10.00', '09.00')
sharks.time = sharks.time.str.replace('20.45 (20.00)', '21.00')

# %%
sharks[['time']] = sharks[['time']].fillna('-1.00')
sharks.time = sharks.time.str.replace('20.45 (20.00)', '21.00')
sharks.time = sharks.time.str.replace('1600', '16.00')
sharks.time = sharks.time.str.replace(' ', '-1.00')

# %%
sharks.time = sharks.time.str.replace('07.00-1.00', '07.00')
sharks.time = sharks.time.str.replace('9.00', '09.00')

# %%
horaMal = sharks[sharks.time == '009.00'].index
sharks.loc[horaMal, 'time'] = '09.00'
horaMal2 = sharks[sharks.time == '109.00'].index
sharks.loc[horaMal2, 'time'] = '09.00'
horaMal3 = sharks[sharks.time == '20.45-1.00(20.00)'].index
sharks.loc[horaMal3, 'time'] = '20.00'
horaMal4 = sharks[sharks.time == '10.00-1.00-1.00-1.0011.00'].index
sharks.loc[horaMal4, 'time'] = '11.00'

# %%
print(sharks['time'].unique())
# Out:
# ['07.45' '-1.00' '17.00' '14.00' '07.00' '15.00' '08.15' '11.00' '10.30'
#  '10.40' '16.50' '09.30' '09.00' '21.50' '09.40' '08.00' '18.00' '17.35'
#  '15.30' '07.30' '22.00' '16.00' '15.01' '13.45' '23.30' '14.30' '18.30'
#  '16.30' '18.45' '06.00' '10.00' '10.44' '13.30' '10.45' '11.20' '11.45'
#  '19.30' '12.00' '08.30' '17.10' '11.15' '08.50' '10.20' '13.20' '12.30'
#  '02.00' '11.30' '17.30' '13.00' '10.43' '23.00' '15.15' '15.40' '19.05'
#  '16.20' '14.34' '15.25' '14.55' '15.45' '15.49' '00.00' '10.15' '18.15'
#  '04.00' '14.50' '13.50' '19.20' '10.25' '16.45' '15.52' '06.15' '14.40'
#  '19.45' '08.45' '20.00' '12.10' '18.05' '11.41' '12.25' '17.51' '10.50'
#  '14.15' '09.45' '06.45' '05.00' '03.30' '06.30' '17.20' '11.10' '17.50'
#  '17.01' '09.57' '17.58' '20.30' '15.19' '10.55' '15.55' '16.05' '14.10'
#  '12.45' '12.50' '14.45' '08.20' '13.24' '11.40' '08.10' '07.56' '17.17'
#  '16.35' '09.05' '07.15' '14.20' '19.28' '12.38' '15.50' '05.45' '13.25'
# ...

# %%
nanCols = sharks.isna().sum()
nanCols[nanCols > 0] # ya no tenemos nulos
# Out:
# Series([], dtype: int64)

# %%
sharks['caseNumber1'] = sharks['caseNumber']
sharks['caseNumber2'] = sharks['caseNumber'] # para poder poner los caseNumber en formato date

# %%
sharks['unnamed22'] = sharks.index
sharks = sharks.rename(columns = {'unnamed22': 'originalIndex'}) # con esto guardamos nuestros índices originales en una de las columnas vacías

# %%
sharks.reset_index(drop = True) # reseteamos los índices
# Out:
#       caseNumber         date    year        type      country  \
# 0     2018.06.09  09-Jun-2018  2018.0     Invalid          usa
# 1     2018.06.08  08-Jun-2018  2018.0  Unprovoked    australia
# 2     2018.06.04  04-Jun-2018  2018.0    Provoked       mexico
# 3     2018.06.03  03-Jun-2018  2018.0  Unprovoked    australia
# 4     2018.06.03  03-Jun-2018  2018.0  Unprovoked       brazil
# ...          ...          ...     ...         ...          ...
# 1553  2001.03.03  03-Mar-2001  2001.0  Unprovoked       brazil
# 1554  2001.02.04  04-Feb-2001  2001.0  Unprovoked    australia
# 1555  2001.01.24  24.Jan.2001  2001.0     Boating    australia
# 1556  2001.01.09  09-Jan-2001  2001.0  Unprovoked          usa
# 1557  2001.01.06  06-Jan-2001  2001.0     Boating  new zealand
#
#                  area                  location      activity  \
# 0              Hawaii              Habush, Oahu       Surfing
# 1     New South Wales        Arrawarra Headland       Surfing
# ...

# %%
sharks = sharks.rename(columns = {'unnamed23': 'hemisphere'})

# %%
sharks = sharks.astype({'time': float}, errors = 'raise')

# %%
sharks.caseNumber = sharks.caseNumber.str.replace('.', '/')
sharks['caseNumber'] = pd.to_datetime(sharks['caseNumber'], yearfirst = True)

# %%
sharks.date = sharks.date.str.replace('-', '/')
sharks['date'] = pd.to_datetime(sharks['date'], dayfirst = True)

# %%
sharks = sharks.astype({'age': int}, errors = 'raise')

# %%
sharks = sharks.astype({'year': int}, errors = 'raise')

# %%
sharks.caseNumber1 = sharks.caseNumber1.str.replace('.', '/')
sharks['caseNumber1'] = pd.to_datetime(sharks['caseNumber1'], yearfirst = True)

# %%
sharks.caseNumber2 = sharks.caseNumber2.str.replace('.', '/')
sharks['caseNumber2'] = pd.to_datetime(sharks['caseNumber2'], yearfirst = True)

# %%
sharks['fatal(y/n)'] = sharks['fatal(y/n)'].map({'True': True, 'False': False})

# %%
indexWhite = sharks[sharks['species'].str.contains('white')].index
sharks.loc[indexWhite, 'species'] = 'White'
indexWhite2 = sharks[sharks['species'].str.contains('White')].index
sharks.loc[indexWhite2, 'species'] = 'White'
indexTiger = sharks[sharks['species'].str.contains('Tiger')].index
sharks.loc[indexTiger, 'species'] = 'Tiger'
indexTiger2 = sharks[sharks['species'].str.contains('tiger')].index
sharks.loc[indexTiger2, 'species'] = 'Tiger'
indexBull = sharks[sharks['species'].str.contains('Bull')].index
sharks.loc[indexBull, 'species'] = 'Bull'
indexBull2 = sharks[sharks['species'].str.contains('bull')].index
sharks.loc[indexBull2, 'species'] = 'Bull'
indexGreyReef = sharks[sharks['species'].str.contains('Grey reef')].index
sharks.loc[indexGreyReef, 'species'] = 'Grey reef'
indexGreyReef2 = sharks[sharks['species'].str.contains('grey reef')].index
sharks.loc[indexGreyReef2, 'species'] = 'Grey reef'
indexLemon = sharks[sharks['species'].str.contains('Lemon')].index
sharks.loc[indexLemon, 'species'] = 'Lemon'
indexLemon2 = sharks[sharks['species'].str.contains('lemon')].index
sharks.loc[indexLemon2, 'species'] = 'Lemon'
indexNurse = sharks[sharks['species'].str.contains('nurse')].index
sharks.loc[indexNurse, 'species'] = 'Nurse'
indexNurse2 = sharks[sharks['species'].str.contains('Nurse')].index
sharks.loc[indexNurse2, 'species'] = 'Nurse'
indexWobbegong = sharks[sharks['species'].str.contains('Wobbegong')].index
sharks.loc[indexWobbegong, 'species'] = 'Wobbegong'
indexWobbegong2 = sharks[sharks['species'].str.contains('wobbegong')].index
sharks.loc[indexWobbegong2, 'species'] = 'Wobbegong'
indexBlacktip = sharks[sharks['species'].str.contains('Blacktip')].index
sharks.loc[indexBlacktip, 'species'] = 'Blacktip'
indexBlacktip2 = sharks[sharks['species'].str.contains('blacktip')].index
sharks.loc[indexBlacktip2, 'species'] = 'Blacktip'
indexCaribbeanReef = sharks[sharks['species'].str.contains('Caribbean reef')].index
sharks.loc[indexCaribbeanReef, 'species'] = 'Caribbean reef'
indexCaribbeanReef2 = sharks[sharks['species'].str.contains('caribbean reef')].index
sharks.loc[indexCaribbeanReef2, 'species'] = 'Caribbean reef'
indexDogfish = sharks[sharks['species'].str.contains('Dogfish')].index
sharks.loc[indexDogfish, 'species'] = 'Dogfish'
indexDogfish2 = sharks[sharks['species'].str.contains('dogfish')].index
sharks.loc[indexDogfish2, 'species'] = 'Dogfish'
indexBlue = sharks[sharks['species'].str.contains('Blue')].index
sharks.loc[indexBlue, 'species'] = 'Blue'
indexBlue2 = sharks[sharks['species'].str.contains('blue')].index
sharks.loc[indexBlue2, 'species'] = 'Blue'
indexMako = sharks[sharks['species'].str.contains('Mako shark')].index
sharks.loc[indexMako, 'species'] = 'Mako shark'
indexMako2 = sharks[sharks['species'].str.contains('mako shark')].index
sharks.loc[indexMako2, 'species'] = 'Mako shark'
indexBronze = sharks[sharks['species'].str.contains('Bronze whaler')].index
sharks.loc[indexBronze, 'species'] = 'Bronze whaler'
indexBronze2 = sharks[sharks['species'].str.contains('bronze whaler')].index
sharks.loc[indexBronze2, 'species'] = 'Bronze whaler'

# %%
indexGalapagos = sharks[sharks['species'].str.contains('Galapagos')].index
sharks.loc[indexGalapagos, 'species'] = 'Galapagos'
indexGalapagos2 = sharks[sharks['species'].str.contains('galapagos')].index
sharks.loc[indexGalapagos2, 'species'] = 'Galapagos'
indexCookiecutter = sharks[sharks['species'].str.contains('Cookiecutter')].index
sharks.loc[indexCookiecutter, 'species'] = 'Cookiecutter'
indexCookiecutter2 = sharks[sharks['species'].str.contains('cookiecutter')].index
sharks.loc[indexCookiecutter2, 'species'] = 'Cookiecutter'
indexSpinner = sharks[sharks['species'].str.contains('Spinner')].index
sharks.loc[indexSpinner, 'species'] = 'Spinner'
indexSpinner2 = sharks[sharks['species'].str.contains('spinner')].index
sharks.loc[indexSpinner2, 'species'] = 'Spinner'
indexPorbeagle = sharks[sharks['species'].str.contains('Porbeagle')].index
sharks.loc[indexPorbeagle, 'species'] = 'Porbeagle'
indexPorbeagle2 = sharks[sharks['species'].str.contains('porbeagle')].index
sharks.loc[indexPorbeagle2, 'species'] = 'Porbeagle'
indexBroadnose = sharks[sharks['species'].str.contains('Broadnose sevengill ')].index
sharks.loc[indexBroadnose, 'species'] = 'Broadnose sevengill'
indexBroadnose2 = sharks[sharks['species'].str.contains('broadnose sevengill ')].index
sharks.loc[indexBroadnose2, 'species'] = 'Broadnose sevengill'
indexHammerhead = sharks[sharks['species'].str.contains('Hammerhead')].index
sharks.loc[indexHammerhead, 'species'] = 'Hammerhead'
indexHammerhead2 = sharks[sharks['species'].str.contains('hammerhead')].index
sharks.loc[indexHammerhead2, 'species'] = 'Hammerhead'
indexSandbar = sharks[sharks['species'].str.contains('Sandbar')].index
sharks.loc[indexSandbar, 'species'] = 'Sandbar'
indexSandbar2 = sharks[sharks['species'].str.contains('sandbar')].index
sharks.loc[indexSandbar2, 'species'] = 'Sandbar'
indexRaggedtooth = sharks[sharks['species'].str.contains('Raggedtooth')].index
sharks.loc[indexRaggedtooth, 'species'] = 'Raggedtooth'
indexRaggedtooth2 = sharks[sharks['species'].str.contains('raggedtooth')].index
sharks.loc[indexRaggedtooth2, 'species'] = 'Raggedtooth'
indexSalmon = sharks[sharks['species'].str.contains('Salmon')].index
sharks.loc[indexSalmon, 'species'] = 'Salmon'
indexSalmon2 = sharks[sharks['species'].str.contains('salmon')].index
sharks.loc[indexSalmon2, 'species'] = 'Salmon'
indexPort = sharks[sharks['species'].str.contains('Port Jackson')].index
sharks.loc[indexPort, 'species'] = 'Port Jackson'
indexPort2 = sharks[sharks['species'].str.contains('port Jackson')].index
sharks.loc[indexPort2, 'species'] = 'Port Jackson'
indexSevengill = sharks[sharks['species'].str.contains('Sevengill')].index
sharks.loc[indexSevengill, 'species'] = 'Sevengill'
indexSevengill2 = sharks[sharks['species'].str.contains('sevengill')].index
sharks.loc[indexSevengill2, 'species'] = 'Sevengill'
indexZambesi = sharks[sharks['species'].str.contains('Zambesi')].index
sharks.loc[indexZambesi, 'species'] = 'Zambesi'
indexZambesi2 = sharks[sharks['species'].str.contains('zambesi')].index
sharks.loc[indexZambesi2, 'species'] = 'Zambesi'

# %%
sharks.species = sharks.species.str.replace(' to ', '')
sharks.species = sharks.species.str.replace(' m ', '')
sharks.species = sharks.species.str.replace("'", '')
sharks.species = sharks.species.str.replace('.', '')
sharks.species = sharks.species.str.replace('0', '')
sharks.species = sharks.species.str.replace('1', '')
sharks.species = sharks.species.str.replace('2', '')
sharks.species = sharks.species.str.replace('3', '')
sharks.species = sharks.species.str.replace('4', '')
sharks.species = sharks.species.str.replace('5', '')
sharks.species = sharks.species.str.replace('6', '')
sharks.species = sharks.species.str.replace('7', '')
sharks.species = sharks.species.str.replace('8', '')
sharks.species = sharks.species.str.replace('9', '')
sharks.species = sharks.species.str.replace('[', '')
sharks.species = sharks.species.str.replace(']', '')

# %%
sharks.species = sharks.species.str.replace('Invalid incident', 'Unknown')
sharks.species = sharks.species.str.replace('Shark involvement not confirmed', 'Unknown')
sharks.species = sharks.species.str.replace('Questionable', 'Unknown')
sharks.species = sharks.species.str.replace('Death may have been duedrowning', 'Unknown')
sharks.species = sharks.species.str.replace('A small shark', 'Unknown')
sharks.species = sharks.species.str.replace('No shark invovlement ', 'Unknown')
sharks.species = sharks.species.str.replace('m shark, probably a smooth hound', 'Unknown')
sharks.species = sharks.species.str.replace('Shark involvement priordeath not confirmed', 'Unknown')
sharks.species = sharks.species.str.replace('Saidinvolve an  shark but more likely damage caused by debris', 'Unknown')
sharks.species = sharks.species.str.replace('No shark involvement', 'Unknown')

# %%
sharks.species = sharks.species.str.replace(' m "black finned shark"', 'Unknown')
sharks.species = sharks.species.str.replace('Unknown incident - shark bite may have precipitated drowning', 'Unknown')
sharks.species = sharks.species.str.replace('Unidentified', 'Unknown')
sharks.species = sharks.species.str.replace('C leucas tooth fragment recovered from kayak', 'Unknown')
sharks.species = sharks.species.str.replace('Shark involvement priordeath unconfired', 'Unknown')
sharks.species = sharks.species.str.replace('\xa0 ', 'Unknown')
sharks.species = sharks.species.str.replace(' m shark; Tooth fragment recovered from hand', 'Unknown')
sharks.species = sharks.species.str.replace('Unknown, injury may be duea stingray', 'Unknown')
sharks.species = sharks.species.str.replace('Species unidentified', 'Unknown')

# %%
sharks.species = sharks.species.str.replace(' shark, -kg shark T', 'Unknown')
sharks.species = sharks.species.str.replace('Unknown, but it was reported that a shark tooth was recovered from the wound', 'Unknown')
sharks.species = sharks.species.str.replace('"small shark"', 'Unknown')
sharks.species = sharks.species.str.replace('Shark involvement questionable', 'Unknown')
sharks.species = sharks.species.str.replace(' sharks, & ', 'Unknown')
sharks.species = sharks.species.str.replace(' m shark', 'Unknown')
sharks.species = sharks.species.str.replace('Unknown Incident', 'Unknown')
sharks.species = sharks.species.str.replace(' cm " blind or brown shark', 'Unknown')
sharks.species = sharks.species.str.replace('Shark involvement doubtful', 'Unknown')
sharks.species = sharks.species.str.replace( 'Unknown species', 'Unknown')

# %%
sharks.species = sharks.species.str.replace(' cm cm "" bite diameter just below left knee', 'Unknown')
sharks.species = sharks.species.str.replace('A \x93small\x94 shark', 'Unknown')
sharks.species = sharks.species.str.replace(' reef shark - or a  m grey-colored shark', 'Unknown')
sharks.species = sharks.species.str.replace(' cm   shark', 'Unknown')
sharks.species = sharks.species.str.replace('small sharks', 'Unknown')
sharks.species = sharks.species.str.replace(' m, -kg shark', 'Unknown')
sharks.species = sharks.species.str.replace(' small spotted catshark, Scyliorhinus canicula', 'Unknown')
sharks.species = sharks.species.str.replace('Not a shark attack; it was a hoax', 'Unknown')
sharks.species = sharks.species.str.replace('Unknown; thoughtbe a barracuda bite', 'Unknown')
sharks.species = sharks.species.str.replace('Reported by media as shark attack, but shark involvement priordeath was not confirmed', 'Unknown')

# %%
sharks.species = sharks.species.str.replace(' "whaler shark"', 'Whaler')
sharks.species = sharks.species.str.replace('"sand shark"', 'Sand')
sharks.species = sharks.species.str.replace(' copper shark', 'Copper')
sharks.species = sharks.species.str.replace('Saidinvolve a shark', 'Unknown')
sharks.species = sharks.species.str.replace('Angel shark, m ', 'Angel')
sharks.species = sharks.species.str.replace('"" shark', 'Unknown')
sharks.species = sharks.species.str.replace('"a small shark"', 'Unknown')
sharks.species = sharks.species.str.replace('Goblin shark, ', 'Goblin')
sharks.species = sharks.species.str.replace('Starry smoothhound shark, m', 'Unknown')
sharks.species = sharks.species.str.replace(' reef shark', 'Reef shark')

# %%
sharks.species = sharks.species.str.replace('Thoughtinvolve a cookie cutter shark', 'Unknown')
sharks.species = sharks.species.str.replace('Shark involvement probable, but not confirmed', 'Unknown')
sharks.species = sharks.species.str.replace('Thoughtinvolve a Bronze whale shark, m', 'Unknown')
sharks.species = sharks.species.str.replace(' mshark', 'Unknown')
sharks.species = sharks.species.str.replace('Shark involvement priordeath was not confirmed', 'Unknown')
sharks.species = sharks.species.str.replace('shark involvement not confirmed', 'Unknown')
sharks.species = sharks.species.str.replace('a small shark', 'Unknown')
sharks.species = sharks.species.str.replace('Invalid', 'Unknown')
sharks.species = sharks.species.str.replace(' tp  shark', 'Unknown')
sharks.species = sharks.species.str.replace('"Unknown"', 'Unknown')

# %%
sharks.species = sharks.species.str.replace('m shark', 'Unknown')
sharks.species = sharks.species.str.replace('small shark', 'Unknown')
sharks.species = sharks.species.str.replace('reef shark, m', 'Reef shark')
sharks.species = sharks.species.str.replace('Reef shark, ', 'Reef shark')
sharks.species = sharks.species.str.replace('juvenile shark', 'Unknown')
sharks.species = sharks.species.str.replace('Shark involvement not cofirmed', 'Unknown')
sharks.species = sharks.species.str.replace('mshark', 'Unknown')
sharks.species = sharks.species.str.replace(' kg shark', 'Unknown')
sharks.species = sharks.species.str.replace('Dusky shark, m', 'Dusky')
sharks.species = sharks.species.str.replace('Reef shark, m', 'Reef shark')

# %%
sharks.species = sharks.species.str.replace('shark', '')

# %%
sharks.species = sharks.species.str.replace('Caribbean reef', 'CaribbeanReef')
sharks.species = sharks.species.str.replace('Reef ', 'Unknown')
sharks.species = sharks.species.str.replace('Bronze whaler', 'BronzeWhaler')
sharks.species = sharks.species.str.replace('--foot ', 'Unknown')
sharks.species = sharks.species.str.replace('Goblin ', 'Goblin')
sharks.species = sharks.species.str.replace('reef ', 'Unknown')
sharks.species = sharks.species.str.replace(' metre ', 'Unknown')
sharks.species = sharks.species.str.replace('reef ?', 'Unknown')
sharks.species = sharks.species.str.replace('-gill ?', 'Unknown')
sharks.species = sharks.species.str.replace('-gill ', 'Unknown')

# %%
sharks.species = sharks.species.str.replace('Grey Unknown', 'GreyReef')
sharks.species = sharks.species.str.replace('Mako ', 'Mako')
sharks.species = sharks.species.str.replace('Port Jackson', 'PortJackson')
sharks.species = sharks.species.str.replace('Angel ', 'Angel')
sharks.species = sharks.species.str.replace('Thresher ', 'Thresher')
sharks.species = sharks.species.str.replace('Unknownm', 'Unknown')
sharks.species = sharks.species.str.replace(' Unknown', 'Unknown')
sharks.species = sharks.species.str.replace('GrayUnknown', 'GreyReef')
sharks.species = sharks.species.str.replace('Sand ', 'Sand')

# %%
sharks.species = sharks.species.str.replace('  ', 'Unknown')
sharks.species = sharks.species.str.replace(' ', 'Unknown')

# %%
display(sharks[sharks['species'] == ''])
# Out:
#      caseNumber       date  year        type        country  \
# 3    2018-06-08 2018-06-08  2018  Unprovoked      australia
# 21   2018-04-25 2018-04-25  2018  Unprovoked      australia
# 37   2018-03-09 2018-03-09  2018  Unprovoked      australia
# 38   2018-03-09 2018-03-09  2018  Unprovoked      australia
# 63   2017-11-13 2017-11-13  2017  Unprovoked      australia
# 72   2017-10-21 2017-10-21  2017  Unprovoked    new zealand
# 217  2016-09-15 2016-09-16  2016  Unprovoked      australia
# 270  2016-06-02 2016-06-02  2016  Unprovoked  new caledonia
# 319  2016-01-02 2016-01-02  2016  Unprovoked      australia
# 448  2015-02-09 2015-02-09  2015  Unprovoked      australia
# 449  2015-02-08 2015-02-08  2015  Unprovoked      australia
# 450  2015-02-05 2015-02-05  2015  Unprovoked      australia
# 457  2015-01-17 2015-01-17  2015     Boating      australia
# 458  2015-01-16 2015-01-16  2015  Unprovoked      australia
# 468  2014-12-28 2014-12-28  2014    Provoked      australia
# ...

# %%
display(sharks[sharks['species'] == 'Unknown?'])
# Out:
#     caseNumber       date  year        type      country               area  \
# 368 2015-09-03 2015-09-03  2015  Unprovoked          usa     South Carolina
# 562 2014-04-24 2014-04-24  2014  Unprovoked    australia  Western Australia
# 584 2014-02-07 2014-02-07  2014  Unprovoked  new zealand       South Island
# 702 2013-02-21 2013-02-21  2013  Unprovoked          usa             Hawaii
#
#                               location      activity           name sex  age  \
# 368         Myrtle Beach, Horry County       Unknown    Chip Wagner   M   -1
# 562  South Passage, south of Coral Bay  Spearfishing           male   M   -1
# 584                       Porpoise Bay       Surfing   Darren Mills   M   28
# 702                     Paia Bay, Maui       Surfing  Jacob Lanskey   M   -1
#
#                                       injury  fatal(y/n)  time   species  \
# 368                        Right foot bitten       False  16.0  Unknown?
# ...

# %%
display(sharks[sharks['species'] == '+Unknown'])
# Out:
#      caseNumber       date  year        type country     area       location  \
# 1201 2008-09-28 2008-09-28  2008  Unprovoked     usa  Florida  Bethune Beach
#
#      activity        name sex  age             injury  fatal(y/n)  time  \
# 1201  Surfing  David Carr   M   40  Right foot bitten       False  11.0
#
#        species investigatorOrSource                    pdf  \
# 1201  +Unknown         S. Petersohn  2008.09.28.a-Carr.pdf
#
#                                             hrefFormula  \
# 1201  http://sharkattackfile.net/spreadsheets/pdf_di...
#
#                                                    href caseNumber1  \
# 1201  http://sharkattackfile.net/spreadsheets/pdf_di...  2008-09-28
#
#      caseNumber2  originalOrder  originalIndex hemisphere
# 1201  2008-09-28         5102.0           1201    Unknown

# %%
print(sharks['species'].unique())
# Out:
# ['Unknown' '' 'Tiger' 'Lemon' 'Bull' 'GreyReef' 'White' 'Wobbegong'
#  'Blacktip' 'Galapagos' 'Nurse' 'Cookiecutter' 'Spinner' 'Porbeagle'
#  'CaribbeanReef' 'Sevengill' 'Blue' 'Dogfish' 'Mako' 'BronzeWhaler'
#  'Hammerhead' 'Unknown?' 'Raggedtooth' 'Goblin' 'Sandbar' 'Salmon'
#  'PortJackson' 'Zambesi' 'Angel' 'Thresher' 'Spurdog' 'Dusky' '+Unknown'
#  'Sand' 'Copper' 'Whaler']

# %%
sharks.shape, sharks_ori_shape # tamaño del df solo con los datos de los ataques a hombres desde 2001 vs al inicio
# Out:
# ((1558, 24), (25723, 24))

# %%
sharks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1558 entries, 2 to 1981
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   caseNumber            1558 non-null   datetime64[ns]
#  1   date                  1558 non-null   datetime64[ns]
#  2   year                  1558 non-null   int64
#  3   type                  1558 non-null   object
#  4   country               1558 non-null   object
#  5   area                  1558 non-null   object
#  6   location              1558 non-null   object
#  7   activity              1558 non-null   object
#  8   name                  1558 non-null   object
#  9   sex                   1558 non-null   object
#  10  age                   1558 non-null   int64
#  11  injury                1558 non-null   object
#  12  fatal(y/n)            1558 non-null   bool
#  13  time                  1558 non-null   float64
# ...

# %%
sharks.to_csv('../DATA/sharks_clean.csv', sep=',', index=False)

# %%
#voy a estudiar los ataques de tiburos desde el año 2001 a 2018 (hasta donde tengo datos) a hombres
